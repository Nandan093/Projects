# %% [markdown]
# # Project 1 : Real Estate Price Prediction

# %%
#importing modules: numpy,pandas, seaborn and matplotlib
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#Loading Real estate dataset into dataSet variable by using pandas
dataSet = pd.read_csv('C:/Users/ADMIN/Desktop/Data Science/Real estate/Real estate.csv')

# %%
# To view first 5 rows dataSet
dataSet.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
# To view last 5 rows dataSet
dataSet.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
#datatype checking 
dataSet.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
#Changing dataSet columns
dataSet.columns = ['No','Date','House_age','MRT_station','Stores','latitude','longitude','price/unit_area']

# %%
dataSet.head()
# Out:
#    No      Date  House_age  MRT_station  Stores  latitude  longitude  \
# 0   1  2012.917       32.0     84.87882      10  24.98298  121.54024
# 1   2  2012.917       19.5    306.59470       9  24.98034  121.53951
# 2   3  2013.583       13.3    561.98450       5  24.98746  121.54391
# 3   4  2013.500       13.3    561.98450       5  24.98746  121.54391
# 4   5  2012.833        5.0    390.56840       5  24.97937  121.54245
#
#    price/unit_area
# 0             37.9
# 1             42.2
# 2             47.3
# 3             54.8
# 4             43.1

# %%
dataSet.describe()
# Out:
#                No         Date   House_age  MRT_station      Stores  \
# count  414.000000   414.000000  414.000000   414.000000  414.000000
# mean   207.500000  2013.148971   17.712560  1083.885689    4.094203
# std    119.655756     0.281967   11.392485  1262.109595    2.945562
# min      1.000000  2012.667000    0.000000    23.382840    0.000000
# 25%    104.250000  2012.917000    9.025000   289.324800    1.000000
# 50%    207.500000  2013.167000   16.100000   492.231300    4.000000
# 75%    310.750000  2013.417000   28.150000  1454.279000    6.000000
# max    414.000000  2013.583000   43.800000  6488.021000   10.000000
#
#          latitude   longitude  price/unit_area
# count  414.000000  414.000000       414.000000
# mean    24.969030  121.533361        37.980193
# std      0.012410    0.015347        13.606488
# min     24.932070  121.473530         7.600000
# 25%     24.963000  121.528085        27.700000
# 50%     24.971100  121.538630        38.450000
# ...

# %%
dataSet.info() #to check any null value exists
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   No               414 non-null    int64
#  1   Date             414 non-null    float64
#  2   House_age        414 non-null    float64
#  3   MRT_station      414 non-null    float64
#  4   Stores           414 non-null    int64
#  5   latitude         414 non-null    float64
#  6   longitude        414 non-null    float64
#  7   price/unit_area  414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 25.9 KB

# %% [markdown]
# # Visualizations

# %%
#Importing seaborn for visualization
import seaborn as sns

# %%
#Relational plots
sns.relplot(x="price/unit_area", y="House_age", data=dataSet)

# %%
sns.relplot(x="price/unit_area", y="House_age", data=dataSet,hue = 'Stores')

# %%
sns.relplot(x="price/unit_area", y="House_age", data=dataSet,hue = 'MRT_station')

# %%
sns.relplot(x="price/unit_area", y="House_age", data=dataSet,col = 'Stores',col_wrap = 2)

# %%
sns.relplot(x="price/unit_area", y="House_age", data=dataSet,hue = 'Stores',palette = 'ch:r=0.8, l=0.95')

# %%
sns.relplot(x="price/unit_area", y="House_age", data=dataSet,hue = 'Stores',sizes=(1,1000))

# %%
sns.relplot(x="Stores", y="House_age", data=dataSet,kind = 'line')

# %%
sns.relplot(x="Stores", y="House_age", data=dataSet,kind = 'line',ci = False)

# %%
sns.relplot(x="Stores", y="House_age", data=dataSet,kind = 'line',ci = 'sd')

# %%
sns.relplot(x="Stores", y="House_age", data=dataSet,kind = 'line',estimator = None )

# %%
sns.relplot(x="price/unit_area", y="House_age", data=dataSet,kind = 'line',estimator = None , hue = 'Stores' )

# %%
sns.relplot(x="Stores", y="House_age", data=dataSet,kind = 'line',estimator = None,marker = True )

# %%
sns.relplot(x="Stores", y="House_age", data=dataSet,kind = 'line',ci = False, markers = True)

# %%
#Lineplot

sns.lineplot(x="Stores", y="House_age", data=dataSet)

# %%
sns.lineplot(x="Stores", y="price/unit_area", data=dataSet,markers = True)

# %%
sns.lineplot(x="MRT_station", y="price/unit_area", data=dataSet)

# %%
sns.lineplot(x="price/unit_area", y="MRT_station", data=dataSet,markers = True)

# %%
#Scatter plot
sns.scatterplot(x="MRT_station", y="price/unit_area", data=dataSet)

# %%
sns.scatterplot(x="MRT_station", y="price/unit_area", hue = 'Stores',data=dataSet)

# %%
sns.scatterplot(x="MRT_station", y="price/unit_area", hue = 'Stores',markers = True,data=dataSet)

# %%
sns.scatterplot(x=dataSet["MRT_station"], y=dataSet["price/unit_area"])

# %%
#Cat plot
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet)

# %%
sns.catplot(y='House_age',x = 'Stores',data = dataSet)

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,jitter = False)

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,kind ='swarm')

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,kind ='box')

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,kind ='swarm',dodge = False)

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,kind ='boxen')

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet.sort_values('House_age'),kind ='boxen',dodge = False)

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,kind ='violin')

# %%
sns.catplot(x='Stores',y = 'price/unit_area',data = dataSet,kind ='violin',split = True,inner = 'sticks')

# %%
sns.catplot(x='Stores',y = 'MRT_station',data = dataSet,kind ='bar')

# %%
sns.catplot(x='Stores',data = dataSet,kind ='count')

# %%
sns.catplot(x='Stores',data = dataSet,kind ='count',palette='ch:0.25')

# %%
sns.catplot(x='Stores',y ='House_age',data = dataSet,kind ='point',pallete = '0.45')

# %%
#Boxplot
sns.boxplot(x = dataSet["House_age"])

# %%
sns.set(style="darkgrid")
sns.boxplot(x = dataSet["price/unit_area"])

# %%
sns.boxplot(x = 'Stores' , data = dataSet)

# %%
sns.boxplot(x='Stores',y = 'price/unit_area', data = dataSet)

# %%
sns.boxplot(x='Stores',y = 'price/unit_area', data = dataSet,palette = 'Accent_r')

# %%
sns.boxplot(x='Stores',y = 'price/unit_area', data = dataSet,palette = 'Accent_r',linewidth = 2.5)

# %%
sns.boxplot(data = dataSet,orient = 'h',palette = 'Set2')

# %%
sns.boxplot(x='Stores',y = 'price/unit_area', data = dataSet)
sns.swarmplot(x='Stores',y = 'price/unit_area', data = dataSet,color = '0.25')

# %%
#Boxen plot
sns.boxenplot(x='price/unit_area',data=dataSet)

# %%
sns.boxenplot(y='price/unit_area',data=dataSet)

# %%
sns.boxenplot(y='price/unit_area',x = 'Stores',data=dataSet)

# %%
sns.boxenplot(y='price/unit_area',x = 'Stores',data=dataSet,palette = 'Set2')

# %%
sns.boxenplot(y='price/unit_area',x = 'Stores',data=dataSet,palette = 'Set2',linewidth = 5)

# %%
#Swarm plot
sns.swarmplot(x='price/unit_area',data=dataSet)

# %%
sns.swarmplot(y='price/unit_area',data=dataSet)

# %%
sns.swarmplot(y='price/unit_area',x = 'Stores',data=dataSet,palette = 'Set2')

# %%
sns.boxplot(x='Stores',y = 'price/unit_area', data = dataSet)
sns.swarmplot(y='price/unit_area',x = 'Stores',data=dataSet,color = '0.2')

# %%
sns.violinplot(x='Stores',y = 'price/unit_area', data = dataSet)
sns.swarmplot(y='price/unit_area',x = 'Stores',data=dataSet,color = 'white', edgecolor='gray')

# %%
#Distplot
sns.distplot(dataSet['Stores'])

# %%
sns.distplot(dataSet['Stores'], hist = False)

# %%
sns.distplot(dataSet['Stores'], hist = False, rug = True)

# %%
sns.distplot(dataSet['Stores'], kde = False)

# %%
sns.distplot(dataSet['Stores'], vertical = True)

# %%
sns.set_color_codes()
sns.distplot(dataSet['price/unit_area'], color = 'r')

# %%
sns.distplot(dataSet['price/unit_area'], color = 'r',norm_hist = False)

# %%
from scipy.stats import norm 
sns.distplot(dataSet['price/unit_area'], color = 'y',fit = norm, kde = False)

# %%
#kde plot
sns.kdeplot(dataSet['price/unit_area'])

# %%
sns.kdeplot(dataSet['price/unit_area'],shade = True)

# %%
sns.kdeplot(dataSet['price/unit_area'],shade = True, color = 'm')

# %%
sns.kdeplot(dataSet['price/unit_area'],dataSet['Stores'])

# %%
sns.kdeplot(dataSet['price/unit_area'],dataSet['Stores'],shade  =True)

# %%
#Heatmap
sns.heatmap(dataSet)

# %%
#Other maps
sns.pairplot(data=dataSet)

# %%
sns.regplot(x = "price/unit_area", y ="MRT_station", data=dataSet)

# %%
sns.regplot(x = "price/unit_area", y ="MRT_station", data=dataSet, order = 3)

# %%
sns.regplot(x = "price/unit_area", y ="MRT_station", data=dataSet, robust = True)

# %%
sns.regplot(x = "price/unit_area", y ="MRT_station", data=dataSet, robust = False)
